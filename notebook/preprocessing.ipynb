# %%
import pandas as pd
import numpy as np
import re
from konlpy.tag import Komoran

# %% [markdown]
# # null 값 및 공백 제거

# %%
categorys = ["China", "english", 'Europe', 'France', 'german', 'Japan', 
            'Korea_1', 'Korea_2', 'Korea_3', 'others', 'russian', 'spanish']

PAT_BLANK = re.compile(r'[\s]')

for category in categorys:
    df = pd.read_csv(f'./crawling/book_info_{category}.csv', index_col=0)
    
    # info가 null인 항목 제거
    df.dropna(axis=0, how='any', subset=["info"], inplace=True)
    
    # 공백 제거
    for idx in df.index:
        info = df.loc[idx]['info']
        df.loc[idx]['info'] = PAT_BLANK.sub(' ', info)
    
    df.to_csv(f'./datasets/book_info_{category}.csv')
    print(df.info(), '\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 718 entries, 67023250 to 74028274
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   718 non-null    object
#  1   img     718 non-null    object
#  2   info    718 non-null    object
# dtypes: object(3)
# memory usage: 38.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3972 entries, 24512355 to 24512341
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   3972 non-null   object
#  1   img     3972 non-null   object
#  2   info    3972 non-null   object
# dtypes: object(3)
# memory usage: 253.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206 entries, 69280130 to 24512357
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   206 non-null    object
#  1   img     206 non-null    object
#  2   info    206 non-null    object
# dtypes: object(3)
# memory usage: 14.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 997 entries, 7464999 to 24512349
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   997 non-null    object
#  1   img     997 non-null    object
#  2   info    997 non-null    object
# dtypes: object(3)
# memory usage: 63.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506 entries, 91327495 to 30121150
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   506 non-null    object
#  1   img     506 non-null    object
#  2   info    506 non-null    object
# dtypes: object(3)
# memory usage: 32.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1390 entries, 64994431 to 15323853
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1390 non-null   object
#  1   img     1390 non-null   object
#  2   info    1390 non-null   object
# dtypes: object(3)
# memory usage: 75.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2427 entries, 14148895 to 47685639
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   2427 non-null   object
#  1   img     2427 non-null   object
#  2   info    2427 non-null   object
# dtypes: object(3)
# memory usage: 140.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10209 entries, 24918001 to 19350577
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   10209 non-null  object
#  1   img     10209 non-null  object
#  2   info    10209 non-null  object
# dtypes: object(3)
# memory usage: 577.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2832 entries, 12141917 to 20096895
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   2832 non-null   object
#  1   img     2832 non-null   object
#  2   info    2832 non-null   object
# dtypes: object(3)
# memory usage: 153.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2227 entries, 24512362 to 24512359
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   2227 non-null   object
#  1   img     2227 non-null   object
#  2   info    2227 non-null   object
# dtypes: object(3)
# memory usage: 134.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 503 entries, 16355308 to 77126900
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   503 non-null    object
#  1   img     503 non-null    object
#  2   info    503 non-null    object
# dtypes: object(3)
# memory usage: 31.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136 entries, 9167968 to 41699094
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   136 non-null    object
#  1   img     136 non-null    object
#  2   info    136 non-null    object
# dtypes: object(3)
# memory usage: 8.3+ KB
# None

# %% [markdown]
# # Tokenizing

# %%
komoran = Komoran()

# %%
print('---', df.iloc[13]['info'], '---')
# Out:
# ---   ---

# %%
info = re.sub(r'^\s*$', ' ', '             \t')
print(info == ' ')
# Out:
# True

# %%
token = komoran.pos('             ')
df_token = pd.DataFrame(token, columns=['word', 'tag'])
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# java.lang.NullPointerException            Traceback (most recent call last)
# <ipython-input-99-f7fdd49b708b> in <module>
# ----> 1 token = komoran.pos('             ')
#       2 df_token = pd.DataFrame(token, columns=['word', 'tag'])
#
# ~\anaconda3\envs\AI_dev_env\lib\site-packages\konlpy\tag\_komoran.py in pos(self, phrase, flatten, join)
#      66             if not sentence:
#      67                 continue
# ---> 68             result = self.jki.analyze(sentence).getTokenList()
#      69             result = [(token.getMorph(), token.getPos()) for token in result]
#      70
#
# java.lang.NullPointerException: java.lang.NullPointerException

# %%
print(df.iloc[13]==' ')
# Out:
# code     False
# title    False
# img      False
# info      True
# Name: 13, dtype: bool

# %%
category = 'Japan'

CSV_ORIGIN = f"./crawling/cleaned_book_info_{category}.csv"
CSV_RESULT = f"./datasets/book_keyword_{category}.csv"

TAG_NORMAL = {'NA', 'NF', 'NNG', 'NNP', 'XR'}

#######################################################

df = pd.read_csv(CSV_ORIGIN, index_col=0)

tokens = []
codes = []

for idx in df.index:
    print(idx)
    # 불필요한 문자 제거
    info = re.sub(r'[^0-9가-힣]', ' ', df.loc[idx]['info'])
    info = re.sub(r'^\s*$', ' ', info)
    if info == ' ':
        continue
    
    # tokenizing
    token = komoran.pos(info)
    df_token = pd.DataFrame(token, columns=['word', 'tag'])
    
    # 추출한 token 한 문장으로 만들어서 저장
    tokens.append(' '.join(df_token[df_token['tag'].isin(TAG_NORMAL)]['word']))
    codes.append(idx)

df_result = df[df.index.isin(codes)].copy()
df_result['info'] = tokens
# df_result.to_csv(CSV_RESULT)
# Out:
# 64994431
# 92094468
# 94448019
# 41828737
# 80858321
# 44183549
# 9183765
# 71383264
# 16366966
# 64101217
# 15968762
# 38922751
# 30181353
# 63792340
# 47688806
# 13160165
# 44377165
# 62114116
# 61833905
# 12655226
# 71028624
# 88322540
# 56936844
# 89594130
# 61120512
# 46257742
# 4081443
# 82616141
# 42753381
# 63693938
# 7981738
# 5478012
# 64990049
# 16366964
# 16366960
# 39046139
# 39046138
# 67158752
# 74801153
# 11310999
# 69333402
# 62114122
# 62114123
# 62114124
# 71729962
# 93982822
# 93982823
# 93982824
# 93982825
# 62160259
# 62160260
# 74028130
# 63689662
# 8020806
# 35203938
# 70961021
# 69610975
# 91860491
# 62161313
# 91224263
# 8317606
# 60789936
# 14212512
# 61784334
# 29641843
# 65283364
# 13573653
# 26035648
# 26035647
# 14436163
# 13533376
# 32449301
# 46546903
# 5986328
# 89379631
# 91127808
# 91127809
# 91127810
# 37922438
# 89018625
# 96033438
# 56895200
# 56895199
# 56895197
# 64470212
# 64470214
# 64470216
# 64704197
# 67137735
# 71755355
# 69333398
# 77259699
# 91224261
# 91224260
# 91159681
# 17591427
# 59272805
# 35197634
# 73020631
# 67707695
# 42797914
# 91729075
# 78576622
# 96173923
# 84916163
# 7901468
# 44338381
# 72301753
# 89960055
# 8699305
# 73807677
# 57654830
# 68793657
# 85430584
# 8690001
# 9105021
# 79689518
# 91860495
# 95313491
# 29131575
# 29131576
# 29131577
# 56851420
# 93627628
# 66533886
# 12269737
# 73783143
# 75237899
# 75237897
# 41110025
# 29033866
# 15323853

# %%
print(df_result)
# Out:
#                                                       title  \
# code
# 64994431                                               가격파괴
# 92094468                                            가나에 아줌마
# 94448019                                            가난을 팝니다
# 41828737                                        가난한 사람들의 무리
# 80858321                                          가만히 손을 보다
# ...                                                     ...
# 75237899                         [특가][세트] 다카노 가즈아키 전작 (총5권)
# 75237897                   [특가][세트] 밀리언셀러클럽 일본 문학 걸작선 (총3권)
# 41110025  [한글 번역] 장갑을 사러 간 아기여우, 금빛여우, 빨간 초, 하나의 촛불 ('니이...
# 29033866                                     [합본] 백년법 (상,하)
# 15323853                [합본] 불패의 검성(劍聖), 미야모토 무사시 (전10권/완결)
#
#                                                         img  \
# code
# 64994431        http://image.yes24.com/goods/64994431/800x0
# 92094468        http://image.yes24.com/goods/92094468/800x0
# 94448019        http://image.yes24.com/goods/94448019/800x0
# 41828737  http://image.yes24.com/momo/TopCate0001/kepub/...
# 80858321        http://image.yes24.com/goods/80858321/800x0
# ...                                                     ...
# 75237899        http://image.yes24.com/goods/75237899/800x0
# 75237897        http://image.yes24.com/goods/75237897/800x0
# 41110025        http://image.yes24.com/goods/41110025/800x0
# 29033866  http://image.yes24.com/momo/TopCate0001/kepub/...
# 15323853  http://image.yes24.com/momo/TopCate0001/kepub/...
#
#                                                        info
# code
# 64994431  소비자 가격 담합 오늘날 경종 장편 걸작 필리핀 전장 고비 야구 과감 열정 인생 구...
# 92094468  국내 최초 소개 일본 주목 재일 교포 작가 후 카 자와 우시오 단편집 여성 여성 문...
# 94448019  야마 노구 바쿠 일본 오키나와 출신 시인 시인 생계 유지 시인 삶 녹록 지 하숙비 ...
# 41828737  미야모토 유리코 의 본명 주조 유리 일본 프롤레타리아 문학 작가 평론가 유 리코 한...
# 80858321  사랑 상처 구원 미 완성 애틋 남녀 달 곰 씁쓸 사랑 감각 문장 냉정 시선 탁월 심...
# ...                                                     ...
# 75237899  다카 노 가즈아키의 작품 작품 읽기 시작 미야베 미유키 에도가와 란포 상 수상 다카...
# 75237897  일본 각종 유수 문학상 수상 작가 대표작 종 밀리언셀러 클럽 일본 문학 걸작선 세트...
# 41110025  한글 번역 장갑 아기 여우 금빛 여우 촛불 키치 한글 일본 원문 제공 키치 일본 동...
# 29033866  죽지 영원 젊음 의 꿈 실현 미래 불로 불사 사회 인류 낙원 인가 일본 최대 화제작...
# 15323853  책 소개 차례 싸움 일본 전설 검 미야모토 무사시 의 이야기 대하소설 미야모토 무사...
#
# [1389 rows x 3 columns]

# %%
df.to_csv(CSV_RESULT)

# %%
info = """전교생의 눈과 앞에 담임선생님의 눈이 예상치 못한 상황에 나에게 시선이 멈추어 있었다  나도 내 자신에게 놀라 지켜보았다 교장선생님 연설처럼 앞산  뒷산이 메아리쳤다  예진이랑  같은 반 되게 해주세요   세상에는 수많은 사랑 이야기가 있다  한 편의 시로 시작했던 사랑 이야기는 이윽고 소설로  음악으로  연극으로  영화로  드라
징용 간 할아버지가 남긴 세 글자를 단서로마침내 손자가 밝혀낸 일본군의 만행 현장   용서할 수는 있어도 잊어서는 안 된다 는 메세지를탁월한 문학적 서사로 풀어낸 최순희의 단편소설 가덕도에 부는 바람  외 6선문호는 할아버지의 쪽지 한 장을 단서로 친구들과 함께 가덕도로 향한다  쪽지에 적힌 세 글자  가덕도   그곳은 아름답고 평화롭기만 하다  섬 곳곳을 배회해 보지만 도무지 실마리를 찾을 수 없다  그러나 모두가 지쳐갈 즈음 눈앞에 드넓은 대밭이 펼쳐진다  대밭 아래는 아무도 상상하지 못한 거대한 방공호가 숨겨져 있다  방공호는 언제부터 존재했을까  이 작은 섬에 방공호가 만들어진 이유는 무엇일까 꼬리에 꼬리를 무는 질문들  하나씩 맞춰지는 퍼즐 조각들  믿을 수 없는 현실이 눈앞에 펼쳐지는데  최순희 작가의 표제작  가덕도에 부는 바람 은 현재와 과거의 시공간을 넘나들어 비로소 우리의 미래까지 내다본다  잊고 지냈던 지난 시절의 뼈아픈 역사  그때 그 사람들 곁으로 우리를 초대하여 미래를 제시한다  주인공들의 생생한 사투리는 마치 그들이 실재하는 듯하다  이 소설을 통하여 지난 역사의 희생자들이 여전히 우리 곁에서 숨 쉬고 있음을 느낄 수 있을 것이다 
"""

# %%
token = komoran.pos(info)
df_token = pd.DataFrame(token, columns=['word', 'tag'])

print(df_token)
# Out:
#      word  tag
# 0       전   MM
# 1      교생  NNP
# 2       의  JKG
# 3       눈  NNG
# 4       과   JC
# ...   ...  ...
# 3405    있   VV
# 3406    을  ETM
# 3407    것  NNB
# 3408    이  VCP
# 3409    다   EC
#
# [3410 rows x 2 columns]

# %% [markdown]
# # Test

# %%
df_spanish = pd.read_csv('./datasets/book_info_spanish.csv', index_col=0)
print(df_spanish)
print(df_spanish.info())
# Out:
#                                                       title  \
# code
# 9167968                      검은 양과 또 다른 우화들 - 지식을만드는지식 소설선집
# 79633118                             경이로운 도시 1 - 세계문학전집 255
# 79633119                             경이로운 도시 2 - 세계문학전집 256
# 18038042                                               고 GO
# 91560829                            고양이는 내게 행복하라고 말했다 (개정판)
# ...                                                     ...
# 61356124                                             2666 5
# 90373622                                            7개의 목소리
# 6139411                                            7인의 미치광이
# 15119005                      Don Quixote - 영어로 읽는 세계문학 250
# 41699094  The Exemplary Novels of Cervantes - 영어로 읽는 세계문...
#
#                                                         img  \
# code
# 9167968   http://image.yes24.com/momo/TopCate0001/kepub/...
# 79633118  http://image.yes24.com/momo/TopCate388/MidCate...
# 79633119  http://image.yes24.com/momo/TopCate388/MidCate...
# 18038042  http://image.yes24.com/momo/TopCate0001/kepub/...
# 91560829        http://image.yes24.com/goods/91560829/800x0
# ...                                                     ...
# 61356124  http://image.yes24.com/momo/TopCate0001/kepub/...
# 90373622        http://image.yes24.com/goods/90373622/800x0
# 6139411   http://image.yes24.com/momo/TopCate0001/kepub/...
# 15119005  http://image.yes24.com/momo/TopCate0001/kepub/...
# 41699094        http://image.yes24.com/goods/41699094/800x0
#
#                                                        info
# code
# 9167968     20세기 중남미 문학에서 ‘초단편소설[掌篇小說]’ 분야의 일인자로 꼽히는 아우구...
# 79633118    천덕꾸러기 도시에서 세계적인 도시로 발돋움한 바르셀로나와뒷골목 부랑아에서 세계적...
# 79633119    천덕꾸러기 도시에서 세계적인 도시로 발돋움한 바르셀로나와뒷골목 부랑아에서 세계적...
# 18038042    절망과 희망 사이에서 방황하는 청춘들을 다시 삶으로 이끌다한국에서 이민한 작가가...
# 91560829    행복은 소리 없이 곁에 다가온 느긋한 고양이 같은 것! 수많은 사람들의 삶을 다...
# ...                                                     ...
# 61356124    로베르토 볼라뇨가르시아 마르케스 이후 라틴 아메리카에 등장한 최고의 작가, 스페...
# 90373622    『7개의 목소리』는 가장 영향력 있는 라틴아메리카 작가 7인과의 대화를 기록한 ...
# 6139411     아르헨티나 현대문학의 선구자이자 제3회 부에노스아이레스 문학상을 수상한 작가 로...
# 15119005    <돈키호테> 영문판.1605년에 제 1부, 1615년에 제2부가 발표된 세르반테...
# 41699094    <모범소설> 영문판.1613년에 출간된 세르반테스의 소설집.‘The Lady C...
#
# [136 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136 entries, 9167968 to 41699094
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   136 non-null    object
#  1   img     136 non-null    object
#  2   info    136 non-null    object
# dtypes: object(3)
# memory usage: 4.2+ KB
# None

# %%
komoran.tagset
# Out:
# {'EC': '연결 어미',
#  'EF': '종결 어미',
#  'EP': '선어말어미',
#  'ETM': '관형형 전성 어미',
#  'ETN': '명사형 전성 어미',
#  'IC': '감탄사',
#  'JC': '접속 조사',
#  'JKB': '부사격 조사',
#  'JKC': '보격 조사',
#  'JKG': '관형격 조사',
#  'JKO': '목적격 조사',
#  'JKQ': '인용격 조사',
#  'JKS': '주격 조사',
#  'JKV': '호격 조사',
#  'JX': '보조사',
#  'MAG': '일반 부사',
#  'MAJ': '접속 부사',
#  'MM': '관형사',
#  'NA': '분석불능범주',
#  'NF': '명사추정범주',
#  'NNB': '의존 명사',
#  'NNG': '일반 명사',
#  'NNP': '고유 명사',
#  'NP': '대명사',
#  'NR': '수사',
#  'NV': '용언추정범주',
#  'SE': '줄임표',
#  'SF': '마침표, 물음표, 느낌표',
#  'SH': '한자',
#  'SL': '외국어',
#  'SN': '숫자',
#  'SO': '붙임표(물결,숨김,빠짐)',
#  'SP': '쉼표,가운뎃점,콜론,빗금',
#  'SS': '따옴표,괄호표,줄표',
#  'SW': '기타기호 (논리수학기호,화폐기호)',
#  'VA': '형용사',
#  'VCN': '부정 지정사',
#  'VCP': '긍정 지정사',
#  'VV': '동사',
#  'VX': '보조 용언',
#  'XPN': '체언 접두사',
#  'XR': '어근',
#  'XSA': '형용사 파생 접미사',
#  'XSN': '명사파생 접미사',
#  'XSV': '동사 파생 접미사'}

# %%
TAG_NORMAL = {'NA', 'NF', 'NNG', 'NNP', 'XR'}

tokens = []

for info in df_spanish['info']:
    info = re.sub(r'[^0-9가-힣]', ' ', info)
    token = komoran.pos(info)
    df_token = pd.DataFrame(token, columns=['word', 'tag'])
    tokens.append(' '.join(df_token[df_token['tag'].isin(TAG_NORMAL)]['word']))

print(tokens)
# Out:
# ['20세기 중남미 문학 단편소설 분야 일인자 아우구스토 몬테로 소의 작품집 우화 합리 모순 인간 현실 풍자 역설 간결 압축 작가 유머 이성 인간 현실 꿋꿋 수단 작용 현실 비판 풍자 속 인간 따뜻 시선 책 스페인 마드리드 소재 알파 출판사 포켓 북 원전 20세기 중남미 문학 단편소설 분야 일인자 아우구스토 몬테로 소의 작품집 우화 합리 모순 인간 현실 풍자 역설 간결 압축 작가 유머 이성 인간 현실 꿋꿋 수단 작용 현실 비판 풍자 속 인간 따뜻 시선 책 스페인 마드리드 소재 알파 출판사 포켓 북 원전 아우구스토 몬테로 소 단편소설 작가 유명 공룡 이다 작품 길이 불과 때 공룡 단어 작품 스페인 이탈리아 중남미 나라 출간 중남미 단편 선집 포함 언어 번역 작품 소설 장르 전통 개념 도그마 독자 도전 작품 문학 비평 대상 다양 변종 작품 창작 동기 공룡 은 멕시코 사회 정치 영향력 행사 뒷거래 시대 정치 문화 유산 인물 비유 해석 그러 단편 작품 관심 작품집 양 우화 을 강화 단편소설 작가 확고 이미지 구축 동시 단편소설 장르 발전 작품집 작품 책 작품집 우화 우화 집 인간 속성 동물 인간 인간 세상 풍자 고전 우화 성격 아이러니 패러디 아포리즘 상호 텍스트 기법 메타픽션 기법 문학 풍부 지적 우화 바퀴벌레 작품 패러디 상호 텍스트 기법 카프카 변신 보르 헤스 뫼비우스의 띠 구조 문학 현실 경계 장자 접지 몽 을 동원 꿈 실재 문학 현실 작가 인물 피고 용인 바퀴벌레 경계 복합 유희 독자 즐거움 기존 작품 전달 의미 동물 구원 부엉이 풍자 작가 원숭이 원숭이 생각 페넬로페 피그말리온 작품 상호 텍스트 기법 메타픽션 기법 활용 대부분 경우 기존 텍스트 의미 우리들의 통념 관습 사고 인식 조롱 의문 제기 페넬로페 의 경우 페넬로페 율리시스 집 해석 제기 그리스 신화 다이달로스 이카로스 피그말리온 조각 작품 겉 배은망덕 제자 여성 자신 특성 한계 망각 인간 풍자 한편 작가 작품 관계 신 인간 관계 생각 측면 작품 스페인 작가 우 나무 노 작품 안개 의 패러디 작품 완성 순간 작가 손 독자 삶 보편 관념 유희 우화 기발 가정 실재 현상 기존 상식 믿음 해석 독자 동시 사고 편협 한계 지적 사자 용서 토끼 믿음 귀뚜라미 선생님 은 인간 자연현상 인간 사회 현상 자기중심 그릇 해석 우화 말 생각 하느님 당나귀 피리 도 마찬가지 통념 인간 사고 속성 지적 장소 벼락 악의 독백 도 엉뚱 가정 해석 사실 주변 일 작품 말 세상 선 악 지배력 행사 느낌 현상 사건 일상 악 사람 현실 작품들쳀다 권력 현자 사
for info in df_spanish['info']:
    info = re.sub(r'[^0-9가-힣]', ' ', info)
    token = komoran.pos(info)
    df_token = pd.DataFrame(token, columns=['word', 'tag'])
    
    tokens_na.update(df_token[df_token['tag'] == 'NA']['word'])
    tokens_nf.update(df_token[df_token['tag'] == 'NF']['word'])

# %%
tokens_na
# Out:
# {'감사히',
#  '구스망에',
#  '구스타브',
#  '굼벵이',
#  '그리뇨텡',
#  '까스뜨로',
#  '깜뿌사노가',
#  '깜뿌사노는',
#  '깜뿌사노와',
#  '꼬르넬리아',
#  '꼬르넬리아는',
#  '꼬르넬리아를',
#  '꼬르넬리아의',
#  '꼬르따도는',
#  '꼬르따도를',
#  '꼬르따디요에',
#  '꼬르따사르',
#  '꼬르따사르가',
#  '꼬르따사르는',
#  '꼬르따사르의',
#  '꼬맹이',
#  '꼰스딴사가',
#  '꼰스딴사에게',
#  '꾸바스는',
#  '꾸바스에',
#  '꾸바스의',
#  '낑까스',
#  '나쯔메',
#  '내러티브',
#  '내러티브와',
#  '네덜란드령',
#  '네비스가',
#  '네비스란',
#  '네비스와',
#  '네비스의',
#  '놋',
#  '느릿한',
#  '다흐블라트',
#  '데상브르',
#  '도스또예프스끼는',
#  '도스토옙스키에',
#  '뒤쫒아가게',
#  '드레퓌스를',
#  '똘레도의',
#  '라쁠라따',
#  '라스',
#  '러브크래프트와',
#  '러브크래프트의',
#  '럭셔리하고',
#  '레시페에',
#  '레트라스',
#  '레퓌블리크',
#  '렉퇴르',
#  '로뻬스',
#  '로사스',
#  '로사스의',
#  '로스켈러스',
#  '로페',
#  '뢸이',
#  '루페를',
#  '리꼬쉐',
#  '리브라르테',
#  '리스펙트로의',
#  '리오델라쁠라따',
#  '마르께스',
#  '말세르반떼스와',
#  '말콤',
#  '맙소',
#  '매튜',
#  '메스트르는',
#  '메스트르의',
#  '멕스',
#  '무뇨스',
#  '미랄례스는',
#  '미랄례스의',
#  '미이챠에게',
#  '바렛은',
#  '발스가',
#  '발스를',
#  '발스의',
#  '벗었다코엘료는',
#  '베넹헬리',
#  '베뚜스따는',
#  '베뚜스따를',
#  '베뚜스따의',
#  '보엠',
#  '부다뻬스뜨의',
#  '부스또스',
#  '부왕령',
#  '부켄뷔름',
#  '브라바',
#  '브라바에서',
#  '브라스',
#  '브라울리오',
#  '브루나',
#  '블라네스에서',
#  '블라카만',
#  '비블리오',
#  '빠스',
#  '빠스와',
#  '뽀르뚜갈',
#  '뽀르뚜갈로',
#  '뽀르뚜갈로부터',
#  '쁘레시오사는',
#  '쁘레시오사에게',
#  '쁘레시오사의',
#  '쁘로그레소',
#  '산쵸여',
#  '상프루아',
#  '새콤한',
#  '섄디의',
#  '선두꼬르따사르',
#  '세르반떼스',
#  '세르반떼스가',
#  '세르반떼스의',
#  '셈페레',
#  '셈페레가',
#  '셈페레와',
#  '셰이프',
#  '소아르스가',
#  '소아르스를',
#  '소아르스의',
#  '시곗바늘이',
#  '쌉싸름한',
#  '아르뮈르',
#  '아르트스',
#  '아를트의',
#  '아사트그가',
#  '아사트의',
#  '아우구스토',
#  '아우구스토는',
#  '아우구스토의',
#  '아이앰어히어로',
#  '아즈텍',
#  '아포칼립스',
#  '아퐁소',
#  '알라스',
#  '알팜브라',
#  '야코프',
#  '야코프는',
#  '야코프를',
#  '야코프와',
#  '야코프와의',
#  '야코프의',
#  '에스떼반',
#  '에스떼파니아',
#  '에스떼파니아가',
#  '에스떼파니아라는',
#  '에스뜨레마두라',
#  '에스빠냐',
#  '에스빠냐어',
#  '에스빠냐어로',
#  '에스빠냐어판',
#  '에스빠냐에서도',
#  '에스빠냐와의',
#  '에스빠냐의',
#  '에스테르',
#  '에스테르는',
#  '에스테르를',
#  '에스테르와의',
#  '에스테르의',
#  '에스피노사가',
#  '에스피노사는',
#  '에스피노사와',
#  '에스피노사의',
#  '오노프레의',
#  '오르페오는',
#  '오르페우',
#  '오페른이라는',
#  '울리세스',
#  '울리세스의',
#  '움베르트',
#  '움틔웠다는',
#  '융프라우도',
#  '이사크를',
#  '이사크의',
#  '이적료를',
#  '자히르',
#  '자히르는',
#  '자히르에',
#  '자히르의',
#  '작가세르반떼스가',
#  '작가페르난두',
#  '작품들쳀다',
#  '저비츠',
#  '저자소개페르난두',
#  '젋은',
#  '주드도이체자이퉁',
#  '주해판본세르반떼스의',
#  '출간에스빠냐의',
#  '취잿거리만',
#  '카브레라',
#  '캄푸스',
#  '커커스',
#  '컨텐츠들이',
#  '켄자스시티',
#  '코르타바녜스의',
#  '코엘료',
#  '코엘료가',
#  '코엘료는',
#  '코엘료다운',
#  '코엘료였기에',
#  '코엘료의',
#  '코엘료조차',
#  '코엘료처럼',
#  '콜름',
#  '콜베니크의',
#  '콤포스텔라',
#  '콤포스텔라로',
#  '쿠쉬너2',
#  '쿳사',
#  '쿳시',
#  '퀄리티를',
#  '퀘베도',
#  '크라스노프를',
#  '크라프츠먼',
#  '크립타나',
#  '터닝',
#  '터닝포인트와도',
#  '터벅터벅',
#  '템',
#  '투르게네프의',
#  '투스케츠',
#  '트리스트럼',
#  '파블리토가',
#  '파우스띠노',
#  '팜므파탈로',
#  '팜므파탈로만',
#  '퍼블리셔스',
#  '퍼블리셔스위클리',
#  '페란도가',
#  '페레즈',
#  '페르난데스',
#  '페르난두',
#  '페르디낭드',
#  '페르민',
#  '페르민과',
#  '페르민에게',
#  '페르민은',
#  '페르민의',
#  '페르민이',
#  '페르민이었다',
#  '페어웰',
#  '페어웰은',
#  '페어웰을',
#  '페티소',
#  '페피타',
#  '푸메로의',
#  '푸블리쿠',
#  '푸엔떼스',
#  '푸익의',
#  '프란세스크',
#  '프랭',
#  '프랭뿐',
#  '프랭에게',
#  '프랭이라는',
#  '프레산은',
#  '플래밍',
#  '피노체트의',
#  '피처스',
#  '하나코엘료는',
#  '한델스블라드',
#  '할멈',
#  '향료들의',
#  '헤르트루디스',
#  '헤르트루디스에게',
#  '헤르트루디스의'}

# %%
tokens_nf
# Out:
# {}
